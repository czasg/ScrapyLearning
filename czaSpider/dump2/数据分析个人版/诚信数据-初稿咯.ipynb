# %% [markdown]
# ## 诚信数据 - 爬虫开发历史记录分析
# + 1. [数据统计](#1.-数据统计)
# + 2. [历史运维统计图](#2.--历史运维统计图)
# + 3. 废弃爬虫 - 开发统计热度图
# + 4. 全部爬虫 - 热度图

# %% [markdown]
# ### 简介
# 爬虫生命周期: **爬虫开发阶段 -> 爬虫运维阶段 -> 爬虫废弃**

# %% [markdown]
# ### 1. 数据统计

# %%
"""
诚信数据总记录25024条, 总计任务836个
其中有过运维记录的爬虫共644个, 现已废弃326个

历史入库爬虫716个, 有过运维记录的爬虫546个(76%), 已废弃任务252个(35%)
"""

# %% [markdown]
# ### 2.  历史运维统计图

# %%
"""
红色为运维时发现异常的爬虫，此类爬虫需要返回开发进行修改
蓝色为运维时发现网站大改版等情况，原爬虫废弃
"""

# %% [markdown]
# ### 3. 废弃爬虫 - 开发统计热度图

# %%
"""
以下数据来源于诚信数据已废弃爬虫
从左至右分别为：
需求岗处理次数、开发岗处理次数、清洗岗处理次数、测试岗处理次数、入库岗处理次数、运维岗处理次数
"""

# %%
"""
对数据取平均值
"""
# Out:
# {'需求岗': 1.0, '开发岗': 13.0, '清洗岗': 7.0, '测试岗': 12.0, '入库岗': 4.0, '运维岗': 4.0}

# %% [markdown]
# ### 4. 全部爬虫 - 热度图

# %%
draw_hot_pic(all_vegetables, all_harvest)
